# %% [markdown]
# # GARCH Stock Forecasting

# %% [markdown]
# ## Read Data

# %%
import sys
import setuptools._distutils
sys.modules["distutils"] = setuptools._distutils

import yfinance as yf

from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from arch import arch_model
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import numpy as np

# %% [markdown]
# ## DIS Volatility

# %%
start = datetime(2015, 1, 1)
end = datetime(2020, 6, 10)

# %%
dis = yf.download("DIS", start=start, end=end)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
returns = 100 * dis.Close.pct_change().dropna()

# %%
plt.figure(figsize=(10,4))
plt.plot(returns)
plt.ylabel('Pct Return', fontsize=16)
plt.title('DIS Returns', fontsize=20)
# Out:
# Text(0.5, 1.0, 'DIS Returns')

# %% [markdown]
# ## PACF (Partial Autocorrelation Function)
# PACF measures the correlation between a time series and its own past values (lags), after removing the effects of the intermediate lags.

# %%
plot_pacf(returns**2)
plt.show()

# %% [markdown]
# ## Fit GARCH(3,3)

# %%
model = arch_model(returns, p=3, q=3)

# %%
model_fit = model.fit()
# Out:
# Iteration:      1,   Func. Count:     10,   Neg. LLF: 228987331916.81836
# Iteration:      2,   Func. Count:     22,   Neg. LLF: 972122275.3439541
# Iteration:      3,   Func. Count:     33,   Neg. LLF: 2730.9388612088237
# Iteration:      4,   Func. Count:     43,   Neg. LLF: 2486.3665574803244
# Iteration:      5,   Func. Count:     53,   Neg. LLF: 2320.02670127094
# Iteration:      6,   Func. Count:     63,   Neg. LLF: 2338.269157561671
# Iteration:      7,   Func. Count:     73,   Neg. LLF: 2357.8409825290237
# Iteration:      8,   Func. Count:     83,   Neg. LLF: 2398.171370169318
# Iteration:      9,   Func. Count:     93,   Neg. LLF: 2296.454025348462
# Iteration:     10,   Func. Count:    102,   Neg. LLF: 2296.4451531382792
# Iteration:     11,   Func. Count:    112,   Neg. LLF: 2296.3440603252266
# Iteration:     12,   Func. Count:    121,   Neg. LLF: 2296.325899347479
# Iteration:     13,   Func. Count:    130,   Neg. LLF: 2296.309104341398
# Iteration:     14,   Func. Count:    139,   Neg. LLF: 2296.3051088729144
# Iteration:     15,   Func. Count:    148,   Neg. LLF: 2296.304156510295
# Iteration:     16,   Func. Count:    157,   Neg. LLF: 2296.304086987601
# Iteration:     17,   Func. Count:    165,   Neg. LLF: 2296.3040869880433
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2296.304086987601
#             Iterations: 17
#             Function evaluations: 165
#             Gradient evaluations: 17

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                    DIS   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2296.30
# Distribution:                  Normal   AIC:                           4608.61
# Method:            Maximum Likelihood   BIC:                           4650.37
#                                         No. Observations:                 1367
# Date:                Mon, Feb 17 2025   Df Residuals:                     1366
# Time:                        21:24:02   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -2.5562e-03  4.300e-02 -5.945e-02      0.953 [-8.683e-02,8.172e-02]
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.5478      0.189      2.895  3.789e-03    [  0.177,  0.919]
# alpha[1]       0.0681  3.919e-02      1.738  8.226e-02 [-8.711e-03,  0.145]
# alpha[2]       0.2036  9.663e-02      2.107  3.509e-02  [1.424e-02,  0.393]
# alpha[3]       0.3208      0.151      2.118  3.419e-02  [2.392e-02,  0.618]
# beta[1]        0.0000      0.151      0.000      1.000    [ -0.295,  0.295]
# beta[2]    1.2815e-15  9.814e-02  1.306e-14      1.000    [ -0.192,  0.192]
# beta[3]        0.2242      0.153      1.464      0.143 [-7.597e-02,  0.524]
# ===========================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# ## Try GARCH(3,0) = ARCH(3)

# %%
model = arch_model(returns, p=3, q=0)

# %%
model_fit = model.fit()
# Out:
# Iteration:      1,   Func. Count:      7,   Neg. LLF: 3333.3686215513844
# Iteration:      2,   Func. Count:     16,   Neg. LLF: 6661.154429482047
# Iteration:      3,   Func. Count:     24,   Neg. LLF: 1202244.9991821581
# Iteration:      4,   Func. Count:     31,   Neg. LLF: 189032.66682512732
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 7937.962107542681
# Iteration:      6,   Func. Count:     45,   Neg. LLF: 2543.258331388853
# Iteration:      7,   Func. Count:     52,   Neg. LLF: 2455.413621020308
# Iteration:      8,   Func. Count:     60,   Neg. LLF: 2312.3851428211947
# Iteration:      9,   Func. Count:     66,   Neg. LLF: 2311.8762993540035
# Iteration:     10,   Func. Count:     72,   Neg. LLF: 2311.202247692054
# Iteration:     11,   Func. Count:     78,   Neg. LLF: 2311.1905571617826
# Iteration:     12,   Func. Count:     84,   Neg. LLF: 2311.189563352272
# Iteration:     13,   Func. Count:     90,   Neg. LLF: 2311.1894180788577
# Iteration:     14,   Func. Count:     96,   Neg. LLF: 2311.1894056589754
# Iteration:     15,   Func. Count:    102,   Neg. LLF: 2311.1894050447536
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2311.1894050447536
#             Iterations: 15
#             Function evaluations: 102
#             Gradient evaluations: 15

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Constant Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                    DIS   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -2311.19
# Distribution:                  Normal   AIC:                           4632.38
# Method:            Maximum Likelihood   BIC:                           4658.48
#                                         No. Observations:                 1367
# Date:                Mon, Feb 17 2025   Df Residuals:                     1366
# Time:                        21:24:12   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu             0.0143  4.002e-02      0.357      0.721 [-6.414e-02,9.271e-02]
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.8612      0.138      6.222  4.904e-10    [  0.590,  1.133]
# alpha[1]       0.0869  4.455e-02      1.950  5.121e-02 [-4.557e-04,  0.174]
# alpha[2]       0.2619  9.096e-02      2.880  3.980e-03  [8.366e-02,  0.440]
# alpha[3]       0.3583      0.169      2.125  3.361e-02  [2.778e-02,  0.689]
# ===========================================================================
#
# Covariance estimator: robust
# """

# %%
rolling_predictions = []
test_size = 365

for i in range(test_size):
    train = returns[:-(test_size-i)]
    model = arch_model(train, p=3, q=0)
    model_fit = model.fit(disp='off')
    pred = model_fit.forecast(horizon=1)
    rolling_predictions.append(np.sqrt(pred.variance.values[-1,:][0]))

# %%
rolling_predictions = pd.Series(rolling_predictions, index=returns.index[-365:])

# %%
plt.figure(figsize=(10,4))
true, = plt.plot(returns[-365:])
preds, = plt.plot(rolling_predictions)
plt.title('Volatility Prediction - Rolling Forecast', fontsize=20)
plt.legend(['True Returns', 'Predicted Volatility'], fontsize=16)

# %% [markdown]
# # S&P 500

# %%
start = datetime(2000, 1, 1)
end = datetime(2020, 6, 10)

# %%
spy = yf.download("SPY", start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
returns = 100 * spy.Close.pct_change().dropna()

# %%
plt.figure(figsize=(10,4))
plt.plot(returns)
plt.ylabel('Pct Return', fontsize=16)
plt.title('SPY Returns', fontsize=20)
# Out:
# Text(0.5, 1.0, 'SPY Returns')

# %% [markdown]
# ## PACF

# %%
plot_pacf(returns**2)
plt.show()

# %% [markdown]
# ## Fit GARCH(2,2)

# %%
model = arch_model(returns, p=2, q=2)

# %%
model_fit = model.fit()
# Out:
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 94800.22765457394
# Iteration:      2,   Func. Count:     21,   Neg. LLF: 63334.71673670182
# Iteration:      3,   Func. Count:     33,   Neg. LLF: 11515.911540497746
# Iteration:      4,   Func. Count:     42,   Neg. LLF: 9536.953105087974
# Iteration:      5,   Func. Count:     51,   Neg. LLF: 7206.487177729843
# Iteration:      6,   Func. Count:     59,   Neg. LLF: 7038.902247356711
# Iteration:      7,   Func. Count:     67,   Neg. LLF: 7041.623359601355
# Iteration:      8,   Func. Count:     76,   Neg. LLF: 7035.778418069282
# Iteration:      9,   Func. Count:     84,   Neg. LLF: 7034.111028514324
# Iteration:     10,   Func. Count:     91,   Neg. LLF: 7034.108735539069
# Iteration:     11,   Func. Count:     98,   Neg. LLF: 7034.108516653407
# Iteration:     12,   Func. Count:    105,   Neg. LLF: 7034.108515424931
# Iteration:     13,   Func. Count:    111,   Neg. LLF: 7034.1085154248885
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7034.108515424931
#             Iterations: 13
#             Function evaluations: 111
#             Gradient evaluations: 13

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                    SPY   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -7034.11
# Distribution:                  Normal   AIC:                           14080.2
# Method:            Maximum Likelihood   BIC:                           14119.5
#                                         No. Observations:                 5140
# Date:                Mon, Feb 17 2025   Df Residuals:                     5139
# Time:                        21:25:45   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0741  1.092e-02      6.787  1.148e-11 [5.271e-02,9.552e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0416  1.005e-02      4.142  3.439e-05 [2.193e-02,6.132e-02]
# alpha[1]       0.0853  2.318e-02      3.679  2.338e-04   [3.986e-02,  0.131]
# alpha[2]       0.1355  2.868e-02      4.726  2.289e-06   [7.933e-02,  0.192]
# beta[1]        0.2551      0.292      0.874      0.382     [ -0.317,  0.827]
# beta[2]        0.4943      0.258      1.919  5.498e-02  [-1.054e-02,  0.999]
# ============================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# ## Rolling Forecast

# %%
rolling_predictions = []
test_size = 365*5

for i in range(test_size):
    train = returns[:-(test_size-i)]
    model = arch_model(train, p=2, q=2)
    model_fit = model.fit(disp='off')
    pred = model_fit.forecast(horizon=1)
    rolling_predictions.append(np.sqrt(pred.variance.values[-1,:][0]))

# %%
rolling_predictions = pd.Series(rolling_predictions, index=returns.index[-365*5:])

# %%
plt.figure(figsize=(10,4))
true, = plt.plot(returns[-365*5:])
preds, = plt.plot(rolling_predictions)
plt.title('Volatility Prediction - Rolling Forecast', fontsize=20)
plt.legend(['True Returns', 'Predicted Volatility'], fontsize=16)

# %% [markdown]
# # How to use the model

# %%
train = returns
model = arch_model(train, p=2, q=2)
model_fit = model.fit(disp='off')

# %%
pred = model_fit.forecast(horizon=7)
future_dates = [returns.index[-1] + timedelta(days=i) for i in range(1,8)]
pred = pd.Series(np.sqrt(pred.variance.values[-1,:]), index=future_dates)

# %%
plt.figure(figsize=(10,4))
plt.plot(pred)
plt.title('Volatility Prediction - Next 7 Days', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Volatility Prediction - Next 7 Days')
